# %% [markdown]
# <a href="https://colab.research.google.com/github/jaewoo-cho/jaewoo/blob/master/53_LSTM%2C_GRU%2C_bi_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LSTM
# LSTM (Long Short-Term Memory) : '단기기억'을 '오래' 기억하기

# %% [markdown]
# # 기본 import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

import tensorflow as tf
from tensorflow import keras

import random
def set_seed(seed = 42):
  tf.keras.utils.set_random_seed(seed)
  tf.config.experimental.enable_op_determinism()

set_seed(42)

# %%
base_path = r'/content/drive/MyDrive/dataset/out'

# %% [markdown]
# #   IMDB 데이터 준비

# %%
# 이전 예제 처럼 IMDB  리뷰 데이터를 로드하고 훈련세트와 검증세트로 나눔
from tensorflow.keras.datasets import imdb
from sklearn.model_selection import train_test_split

(train_input, train_target), (test_input, test_target) = imdb.load_data(
    num_words=500)

train_input, val_input, train_target, val_target = train_test_split(
    train_input, train_target, test_size=0.2, random_state=42)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
max_len = 100

# %%
# ↓ 각 샘플의 길이를 100에 맞추고 부족할때는 패딩을 추가
train_seq = pad_sequences(train_input, maxlen=max_len)
val_seq = pad_sequences(val_input, maxlen=max_len)
test_seq = pad_sequences(test_input, maxlen=max_len)

# %% [markdown]
# # ■ LSTM
#
# **tf.keras.layers.LSTM**
#
# https://www.tensorflow.org/api_docs/python/tf/keras/layers/LSTM
#
# ```python
# tf.keras.layers.LSTM(
#     units,
#     activation='tanh',
#     recurrent_activation='sigmoid',
#     use_bias=True,
#     kernel_initializer='glorot_uniform',
#     recurrent_initializer='orthogonal',
#     bias_initializer='zeros',
#     unit_forget_bias=True,
#     kernel_regularizer=None,
#     recurrent_regularizer=None,
#     bias_regularizer=None,
#     activity_regularizer=None,
#     kernel_constraint=None,
#     recurrent_constraint=None,
#     bias_constraint=None,
#     dropout=0.0,
#     recurrent_dropout=0.0,
#     seed=None,
#     return_sequences=False,
#     return_state=False,
#     go_backwards=False,
#     stateful=False,
#     unroll=False,
#     use_cudnn='auto',
#     **kwargs
# )
# ```

# %%
model = keras.Sequential()
model.add(keras.layers.Input(shape=(max_len,)))
model.add(keras.layers.Embedding(500, 16))
model.add(keras.layers.LSTM(units=8))
model.add(keras.layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 100, 16)        │         8,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 8)              │           800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,809 (34.41 KB)
#  Trainable params: 8,809 (34.41 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
"""
Model: "sequential"
┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
│ embedding (Embedding)           │ (None, 100, 16)        │         8,000 │


│ lstm (LSTM)                     │ (None, 8)              │           800 │
        # ①입력 parameter : 16 inputs x 8 units = 128개
        # ②은닉상태 param  : 8 x 8 = 64개
        # ③bias   :   8 개

        # ④: ① + ② + ③ = 200개

        # 전체 parameter 는
        #  4 x ④200개 => 800개.
          #  ↑ 4 는 LSTM 셀 내의 각 게이트 (입력 게이트, 출력 게이트, 포겟 게이트, 셀 상태 업데이트)
          #    에 해당하는 파라미터의 개수

        ★LSTM의 파라미터 개수★
            => 4gates x units x (units + inputs + 1)
            => ex) 4 x 8 x (8 + 16 + 1) => 800


│ dense (Dense)                   │ (None, 1)              │             9 │

 Total params: 8,809 (34.41 KB)
 Trainable params: 8,809 (34.41 KB)
 Non-trainable params: 0 (0.00 B)

"""
None

# %%
base_path = r'/content/drive/MyDrive/dataset/out'

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate=1e-4)
model.compile(optimizer=rmsprop, loss='binary_crossentropy',
              metrics=['accuracy'])

checkpoint_cb = keras.callbacks.ModelCheckpoint(
    os.path.join(base_path, 'best-lstm-model.keras'),
    save_best_only=True)
early_stopping_cb = keras.callbacks.EarlyStopping(patience=3,
                                                  restore_best_weights=True)

history = model.fit(train_seq, train_target, epochs=100, batch_size=64,
                    validation_data=(val_seq, val_target),
                    callbacks=[checkpoint_cb, early_stopping_cb])
# Out:
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.5110 - loss: 0.6929 - val_accuracy: 0.5864 - val_loss: 0.6911
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.5784 - loss: 0.6907 - val_accuracy: 0.6258 - val_loss: 0.6874
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6217 - loss: 0.6858 - val_accuracy: 0.6562 - val_loss: 0.6765
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.6681 - loss: 0.6682 - val_accuracy: 0.7096 - val_loss: 0.6177
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.7180 - loss: 0.6006 - val_accuracy: 0.7248 - val_loss: 0.5760
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7282 - loss: 0.5690 - val_accuracy: 0.7404 - val_loss: 0.5555
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7481 - loss: 0.5465 - val_accuracy: 0.7450 - val_loss: 0.5383
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.7600 - loss: 0.5274 - val_accuracy: 0.7588 - val_loss: 0.5216
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.7688 - loss: 0.5110 - val_accuracy: 0.7698 - val_loss: 0.5076
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7777 - loss: 0.4972 - val_accuracy: 0.7746 - val_loss: 0.4959
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7831 - loss: 0.4853 - val_accuracy: 0.7802 - val_loss: 0.4862
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7885 - loss: 0.4750 - val_accuracy: 0.7850 - val_loss: 0.4781
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7936 - loss: 0.4662 - val_accuracy: 0.7874 - val_loss: 0.4713
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7961 - loss: 0.4585 - val_accuracy: 0.7876 - val_loss: 0.4659
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8009 - loss: 0.4519 - val_accuracy: 0.7904 - val_loss: 0.4614
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8036 - loss: 0.4461 - val_accuracy: 0.7920 - val_loss: 0.4577
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8054 - loss: 0.4411 - val_accuracy: 0.7900 - val_loss: 0.4548
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8083 - loss: 0.4369 - val_accuracy: 0.7898 - val_loss: 0.4524
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8104 - loss: 0.4332 - val_accuracy: 0.7908 - val_loss: 0.4504
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8117 - loss: 0.4300 - val_accuracy: 0.7904 - val_loss: 0.4488
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8128 - loss: 0.4273 - val_accuracy: 0.7902 - val_loss: 0.4475
# Epoch 22/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8135 - loss: 0.4249 - val_accuracy: 0.7888 - val_loss: 0.4463
# Epoch 23/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8139 - loss: 0.4228 - val_accuracy: 0.7894 - val_loss: 0.4453
# Epoch 24/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8139 - loss: 0.4210 - val_accuracy: 0.7886 - val_loss: 0.4444
# Epoch 25/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.8144 - loss: 0.4194 - val_accuracy: 0.7884 - val_loss: 0.4436
# Epoch 26/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8152 - loss: 0.4179 - val_accuracy: 0.7902 - val_loss: 0.4429
# Epoch 27/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8148 - loss: 0.4166 - val_accuracy: 0.7914 - val_loss: 0.4422
# Epoch 28/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8140 - loss: 0.4154 - val_accuracy: 0.7914 - val_loss: 0.4416
# Epoch 29/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8145 - loss: 0.4144 - val_accuracy: 0.7932 - val_loss: 0.4410
# Epoch 30/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8139 - loss: 0.4134 - val_accuracy: 0.7940 - val_loss: 0.4405
# Epoch 31/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8141 - loss: 0.4125 - val_accuracy: 0.7936 - val_loss: 0.4400
# Epoch 32/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8137 - loss: 0.4117 - val_accuracy: 0.7940 - val_loss: 0.4395
# Epoch 33/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8138 - loss: 0.4109 - val_accuracy: 0.7936 - val_loss: 0.4391
# Epoch 34/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8141 - loss: 0.4102 - val_accuracy: 0.7946 - val_loss: 0.4387
# Epoch 35/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8147 - loss: 0.4095 - val_accuracy: 0.7944 - val_loss: 0.4384
# Epoch 36/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8151 - loss: 0.4089 - val_accuracy: 0.7946 - val_loss: 0.4381
# Epoch 37/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8153 - loss: 0.4083 - val_accuracy: 0.7934 - val_loss: 0.4379
# Epoch 38/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8170 - loss: 0.4077 - val_accuracy: 0.7940 - val_loss: 0.4376
# Epoch 39/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8170 - loss: 0.4072 - val_accuracy: 0.7932 - val_loss: 0.4375
# Epoch 40/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8162 - loss: 0.4067 - val_accuracy: 0.7938 - val_loss: 0.4373
# Epoch 41/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.8163 - loss: 0.4061 - val_accuracy: 0.7940 - val_loss: 0.4372
# Epoch 42/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8160 - loss: 0.4057 - val_accuracy: 0.7940 - val_loss: 0.4370
# Epoch 43/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8167 - loss: 0.4052 - val_accuracy: 0.7936 - val_loss: 0.4370
# Epoch 44/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8166 - loss: 0.4047 - val_accuracy: 0.7930 - val_loss: 0.4369
# Epoch 45/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8167 - loss: 0.4043 - val_accuracy: 0.7934 - val_loss: 0.4368
# Epoch 46/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8169 - loss: 0.4038 - val_accuracy: 0.7934 - val_loss: 0.4368
# Epoch 47/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8173 - loss: 0.4034 - val_accuracy: 0.7938 - val_loss: 0.4368
# Epoch 48/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8173 - loss: 0.4030 - val_accuracy: 0.7940 - val_loss: 0.4368
# Epoch 49/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8171 - loss: 0.4025 - val_accuracy: 0.7944 - val_loss: 0.4368
# Epoch 50/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8166 - loss: 0.4021 - val_accuracy: 0.7944 - val_loss: 0.4368
# Epoch 51/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8164 - loss: 0.4017 - val_accuracy: 0.7942 - val_loss: 0.4368
# Epoch 52/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8167 - loss: 0.4013 - val_accuracy: 0.7944 - val_loss: 0.4368

# %%
early_stopping_cb.best_epoch
# Out:
# 48

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# # 순환층에 드롭아웃 적용

# %%
# 완전연결신경망과 CNN 에서는 Dropout 클래스를 사용해서 dropout 을 적용했었다
# 순환층은 '자체적으로 dropout 기능을 제공'

# SimpleRNN, LSTM 클래스에 제공하는 2개의 dropout 매개변수
#   dropout= : 셀의 '입력'에 dropout 적용
#   recurrent_dropout= : 순환되는 '은닉상태'에 dropout 적용
#                        ※ recurrent_dropout 는 GPU를 통한 훈련 못함..

#  아래 예제에선 dropout= 만 사용함..

# %%
model2 = keras.Sequential()
model2.add(keras.layers.Input(shape=(max_len,)))
model2.add(keras.layers.Embedding(500, 16))
model2.add(keras.layers.LSTM(units=8, dropout=0.3)) # dropout 30%
model2.add(keras.layers.Dense(1, activation='sigmoid'))

model2.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ (None, 100, 16)        │         8,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 8)              │           800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,809 (34.41 KB)
#  Trainable params: 8,809 (34.41 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate=1e-4)
model2.compile(optimizer=rmsprop, loss='binary_crossentropy',
              metrics=['accuracy'])

checkpoint_cb = keras.callbacks.ModelCheckpoint(
    os.path.join(base_path, 'best-dropout-model.keras'),
    save_best_only=True)
early_stopping_cb = keras.callbacks.EarlyStopping(patience=3,
                                                  restore_best_weights=True)

history2 = model2.fit(train_seq, train_target, epochs=100, batch_size=64,
                    validation_data=(val_seq, val_target),
                    callbacks=[checkpoint_cb, early_stopping_cb])
# Out:
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.5145 - loss: 0.6930 - val_accuracy: 0.5546 - val_loss: 0.6923
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5619 - loss: 0.6920 - val_accuracy: 0.5872 - val_loss: 0.6909
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6026 - loss: 0.6902 - val_accuracy: 0.6164 - val_loss: 0.6879
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.6257 - loss: 0.6865 - val_accuracy: 0.6406 - val_loss: 0.6809
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6458 - loss: 0.6773 - val_accuracy: 0.6486 - val_loss: 0.6513
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6848 - loss: 0.6394 - val_accuracy: 0.7208 - val_loss: 0.6041
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7198 - loss: 0.5997 - val_accuracy: 0.7310 - val_loss: 0.5860
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7326 - loss: 0.5804 - val_accuracy: 0.7364 - val_loss: 0.5722
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.7458 - loss: 0.5618 - val_accuracy: 0.7530 - val_loss: 0.5525
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7549 - loss: 0.5479 - val_accuracy: 0.7516 - val_loss: 0.5480
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7634 - loss: 0.5337 - val_accuracy: 0.7580 - val_loss: 0.5328
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7698 - loss: 0.5203 - val_accuracy: 0.7562 - val_loss: 0.5290
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7742 - loss: 0.5099 - val_accuracy: 0.7674 - val_loss: 0.5149
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.7796 - loss: 0.5000 - val_accuracy: 0.7638 - val_loss: 0.5109
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7813 - loss: 0.4916 - val_accuracy: 0.7728 - val_loss: 0.4965
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.7863 - loss: 0.4829 - val_accuracy: 0.7736 - val_loss: 0.4912
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.7900 - loss: 0.4736 - val_accuracy: 0.7786 - val_loss: 0.4847
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7908 - loss: 0.4681 - val_accuracy: 0.7790 - val_loss: 0.4792
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7957 - loss: 0.4608 - val_accuracy: 0.7774 - val_loss: 0.4762
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7987 - loss: 0.4565 - val_accuracy: 0.7802 - val_loss: 0.4736
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7961 - loss: 0.4506 - val_accuracy: 0.7836 - val_loss: 0.4689
# Epoch 22/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.7972 - loss: 0.4478 - val_accuracy: 0.7882 - val_loss: 0.4632
# Epoch 23/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.8023 - loss: 0.4423 - val_accuracy: 0.7852 - val_loss: 0.4641
# Epoch 24/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8029 - loss: 0.4391 - val_accuracy: 0.7856 - val_loss: 0.4571
# Epoch 25/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8027 - loss: 0.4375 - val_accuracy: 0.7858 - val_loss: 0.4577
# Epoch 26/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.8056 - loss: 0.4343 - val_accuracy: 0.7858 - val_loss: 0.4592
# Epoch 27/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8060 - loss: 0.4317 - val_accuracy: 0.7866 - val_loss: 0.4538
# Epoch 28/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8093 - loss: 0.4307 - val_accuracy: 0.7920 - val_loss: 0.4526
# Epoch 29/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.8097 - loss: 0.4274 - val_accuracy: 0.7894 - val_loss: 0.4539
# Epoch 30/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8052 - loss: 0.4292 - val_accuracy: 0.7904 - val_loss: 0.4473
# Epoch 31/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8128 - loss: 0.4233 - val_accuracy: 0.7908 - val_loss: 0.4487
# Epoch 32/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8098 - loss: 0.4228 - val_accuracy: 0.7922 - val_loss: 0.4489
# Epoch 33/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.8109 - loss: 0.4198 - val_accuracy: 0.7902 - val_loss: 0.4500

# %%
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# # ■ 순환층 2개 연결하기
# ### 순환층 연결시 주의!
# - 순환층의 은닉상태는 샘플의 마지막 스텝에 대한 은닉 상태만 다음층으로 전달한다
# - 그러나, 순환층을 쌓게 되면 모든 순환층에는 순차 데이터가 필요하다.
# - 따라서
#     - 앞쪽의 순환층은 '모든 타임스텝'에 대한 은닉상태를 출력해야 하고,
#     - 마지막 순환층만 '마지막 타임스텝의 은닉상태'를 출력해야 한다

# %% [markdown]
# ## return_sequences=True
# 모든 타임스텝에 대한 은닉상태 출력 (2차원 출력)

# %%
model3 = keras.Sequential()
model3.add(keras.layers.Input(shape=(max_len,)))
model3.add(keras.layers.Embedding(500, 16))
model3.add(keras.layers.LSTM(units=8, dropout=0.3, return_sequences=True))
model3.add(keras.layers.LSTM(units=8, dropout=0.3))
model3.add(keras.layers.Dense(1, activation='sigmoid'))

model3.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)         │ (None, 100, 16)        │         8,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 100, 8)         │           800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 8)              │           544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,353 (36.54 KB)
#  Trainable params: 9,353 (36.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
"""
Model: "sequential_3"
┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
│ embedding_3 (Embedding)         │ (None, 100, 16)        │         8,000 │
├─────────────────────────────────┼────────────────────────┼───────────────┤
│ lstm_3 (LSTM)                   │ (None, 100, 8)         │           800 │
        # [출력크기]
        # 첫번째 LSTM 층이 모든 타입스텝 (100개) 의 은닉상태를 출력하기 때문에
        # 출력크기가 (?, 100, 8) 로 출력됨 (2차원 출력)

        # [첫번째 LSTM 의 parameter]
            => 4gates x units x (units + inputs + 1)
            => ex) 4 x 8 x (8 + 16 + 1) => 800


│ lstm_4 (LSTM)                   │ (None, 8)              │           544 │
        # [출력크기]
        # 마지막 LSTM 층의 출력크기는 마지막 타임스텝의 은닉상태만 출력하기 때문에
        # 출력크기가 (?, 8) 이다.

        # [두번째 LSTM 의 parameter]
        # 두 번째 LSTM의 경우, '첫 번째 LSTM의 출력'이 '두 번째 LSTM의 입력'이 됩니다.
        # 따라서 두 번째 LSTM의 입력 피처 수는 첫 번째 LSTM의 유닛 수와 동일
            => units x (units + inputs + 1)

       #  4 gates x 8 x (8 + 8 + 1) => 544

│ dense_2 (Dense)                 │ (None, 1)              │             9 │
└─────────────────────────────────┴────────────────────────┴───────────────┘
 Total params: 9,353 (36.54 KB)
 Trainable params: 9,353 (36.54 KB)
 Non-trainable params: 0 (0.00 B)

"""
None

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate=1e-4)
model3.compile(optimizer=rmsprop, loss='binary_crossentropy',
              metrics=['accuracy'])

checkpoint_cb = keras.callbacks.ModelCheckpoint(
    os.path.join(base_path, 'best-2rnn-model.keras'),
    save_best_only=True)
early_stopping_cb = keras.callbacks.EarlyStopping(patience=3,
                                                  restore_best_weights=True)

history3 = model3.fit(train_seq, train_target, epochs=100, batch_size=64,
                    validation_data=(val_seq, val_target),
                    callbacks=[checkpoint_cb, early_stopping_cb])
# Out:
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.5235 - loss: 0.6927 - val_accuracy: 0.5738 - val_loss: 0.6904
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.5854 - loss: 0.6888 - val_accuracy: 0.6384 - val_loss: 0.6765
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.6495 - loss: 0.6604 - val_accuracy: 0.6932 - val_loss: 0.5969
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.7134 - loss: 0.5717 - val_accuracy: 0.7300 - val_loss: 0.5459
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7405 - loss: 0.5346 - val_accuracy: 0.7478 - val_loss: 0.5202
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.7571 - loss: 0.5090 - val_accuracy: 0.7558 - val_loss: 0.5120
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.7712 - loss: 0.4930 - val_accuracy: 0.7612 - val_loss: 0.5026
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7732 - loss: 0.4813 - val_accuracy: 0.7716 - val_loss: 0.4902
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.7836 - loss: 0.4727 - val_accuracy: 0.7662 - val_loss: 0.4928
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7806 - loss: 0.4711 - val_accuracy: 0.7742 - val_loss: 0.4794
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7831 - loss: 0.4691 - val_accuracy: 0.7776 - val_loss: 0.4795
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.7909 - loss: 0.4590 - val_accuracy: 0.7828 - val_loss: 0.4705
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.7906 - loss: 0.4552 - val_accuracy: 0.7762 - val_loss: 0.4754
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.7940 - loss: 0.4542 - val_accuracy: 0.7844 - val_loss: 0.4670
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.7940 - loss: 0.4510 - val_accuracy: 0.7806 - val_loss: 0.4688
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7992 - loss: 0.4484 - val_accuracy: 0.7820 - val_loss: 0.4728
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.7982 - loss: 0.4452 - val_accuracy: 0.7812 - val_loss: 0.4698

# %%
plt.plot(history3.history['loss'])
plt.plot(history3.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# # ■ GRU 신경망
# Gated Recurrent Unit
#
# https://www.tensorflow.org/api_docs/python/tf/keras/layers/GRU
#
# ```python
# tf.keras.layers.GRU(
#     units,
#     activation='tanh',
#     recurrent_activation='sigmoid',
#     use_bias=True,
#     kernel_initializer='glorot_uniform',
#     recurrent_initializer='orthogonal',
#     bias_initializer='zeros',
#     kernel_regularizer=None,
#     recurrent_regularizer=None,
#     bias_regularizer=None,
#     activity_regularizer=None,
#     kernel_constraint=None,
#     recurrent_constraint=None,
#     bias_constraint=None,
#     dropout=0.0,
#     recurrent_dropout=0.0,
#     seed=None,
#     return_sequences=False,
#     return_state=False,
#     go_backwards=False,
#     stateful=False,
#     unroll=False,
#     reset_after=True,
#     use_cudnn='auto',
#     **kwargs
# )
# ```

# %%
model4 = keras.Sequential()
model4.add(keras.layers.Input(shape=(max_len,)))
model4.add(keras.layers.Embedding(500, 16))
model4.add(keras.layers.GRU(units=8))
model4.add(keras.layers.Dense(1, activation='sigmoid'))

model4.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_3 (Embedding)         │ (None, 100, 16)        │         8,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru (GRU)                       │ (None, 8)              │           624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,633 (33.72 KB)
#  Trainable params: 8,633 (33.72 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
"""
Model: "sequential_4"
┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
│ embedding_4 (Embedding)         │ (None, 100, 16)        │         8,000 │
├─────────────────────────────────┼────────────────────────┼───────────────┤
│ gru (GRU)                       │ (None, 8)              │           624 │

      # 입력 parameter : 16 inputs x 8 units = 128개
      # 은닉상태 param : 8 x 8 = 64개
      # bias 가 뉴런마다 : 8개

      # 합하면 200개
      # 이런셀이 3개  200 * 3 => 600개?

      # TF GRU 는 내부적으로 작은 셀마다 하나의 bias 가 추가됨.
      #  작은셀3개 x 8개 units = 24개.


│ dense_3 (Dense)                 │ (None, 1)              │             9 │
└─────────────────────────────────┴────────────────────────┴───────────────┘
 Total params: 8,633 (33.72 KB)
 Trainable params: 8,633 (33.72 KB)
 Non-trainable params: 0 (0.00 B)
"""
None

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate=1e-4)
model4.compile(optimizer=rmsprop, loss='binary_crossentropy',
              metrics=['accuracy'])

checkpoint_cb = keras.callbacks.ModelCheckpoint(
    os.path.join(base_path, 'best-gru-model.keras'),
    save_best_only=True)
early_stopping_cb = keras.callbacks.EarlyStopping(patience=3,
                                                  restore_best_weights=True)

history4 = model4.fit(train_seq, train_target, epochs=100, batch_size=64,
                    validation_data=(val_seq, val_target),
                    callbacks=[checkpoint_cb, early_stopping_cb])
# Out:
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.5052 - loss: 0.6931 - val_accuracy: 0.5206 - val_loss: 0.6928
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5532 - loss: 0.6925 - val_accuracy: 0.5616 - val_loss: 0.6921
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5831 - loss: 0.6917 - val_accuracy: 0.5714 - val_loss: 0.6911
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.5901 - loss: 0.6903 - val_accuracy: 0.5844 - val_loss: 0.6893
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6033 - loss: 0.6882 - val_accuracy: 0.5938 - val_loss: 0.6866
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6136 - loss: 0.6849 - val_accuracy: 0.6036 - val_loss: 0.6822
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6197 - loss: 0.6796 - val_accuracy: 0.6120 - val_loss: 0.6752
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.6300 - loss: 0.6713 - val_accuracy: 0.6294 - val_loss: 0.6640
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6418 - loss: 0.6578 - val_accuracy: 0.6488 - val_loss: 0.6453
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6644 - loss: 0.6351 - val_accuracy: 0.6844 - val_loss: 0.6111
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6996 - loss: 0.5917 - val_accuracy: 0.7326 - val_loss: 0.5492
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7397 - loss: 0.5360 - val_accuracy: 0.7484 - val_loss: 0.5242
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7523 - loss: 0.5158 - val_accuracy: 0.7634 - val_loss: 0.5107
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7617 - loss: 0.5014 - val_accuracy: 0.7724 - val_loss: 0.5008
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7712 - loss: 0.4883 - val_accuracy: 0.7750 - val_loss: 0.4949
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.7816 - loss: 0.4780 - val_accuracy: 0.7762 - val_loss: 0.4916
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7873 - loss: 0.4701 - val_accuracy: 0.7766 - val_loss: 0.4870
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.7921 - loss: 0.4630 - val_accuracy: 0.7782 - val_loss: 0.4798
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.7938 - loss: 0.4567 - val_accuracy: 0.7816 - val_loss: 0.4736
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7963 - loss: 0.4512 - val_accuracy: 0.7846 - val_loss: 0.4702
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.7992 - loss: 0.4466 - val_accuracy: 0.7868 - val_loss: 0.4677
# Epoch 22/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8031 - loss: 0.4426 - val_accuracy: 0.7878 - val_loss: 0.4655
# Epoch 23/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8064 - loss: 0.4392 - val_accuracy: 0.7868 - val_loss: 0.4636
# Epoch 24/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8089 - loss: 0.4364 - val_accuracy: 0.7880 - val_loss: 0.4621
# Epoch 25/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8102 - loss: 0.4341 - val_accuracy: 0.7888 - val_loss: 0.4608
# Epoch 26/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8112 - loss: 0.4320 - val_accuracy: 0.7894 - val_loss: 0.4597
# Epoch 27/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8121 - loss: 0.4303 - val_accuracy: 0.7878 - val_loss: 0.4587
# Epoch 28/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.8134 - loss: 0.4288 - val_accuracy: 0.7882 - val_loss: 0.4578
# Epoch 29/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8133 - loss: 0.4274 - val_accuracy: 0.7890 - val_loss: 0.4570
# Epoch 30/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8134 - loss: 0.4262 - val_accuracy: 0.7908 - val_loss: 0.4562
# Epoch 31/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8124 - loss: 0.4250 - val_accuracy: 0.7892 - val_loss: 0.4554
# Epoch 32/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.8128 - loss: 0.4240 - val_accuracy: 0.7900 - val_loss: 0.4547
# Epoch 33/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8132 - loss: 0.4230 - val_accuracy: 0.7906 - val_loss: 0.4540
# Epoch 34/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8131 - loss: 0.4220 - val_accuracy: 0.7908 - val_loss: 0.4533
# Epoch 35/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.8144 - loss: 0.4211 - val_accuracy: 0.7894 - val_loss: 0.4527
# Epoch 36/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8145 - loss: 0.4203 - val_accuracy: 0.7898 - val_loss: 0.4521
# Epoch 37/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8139 - loss: 0.4194 - val_accuracy: 0.7904 - val_loss: 0.4515
# Epoch 38/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8147 - loss: 0.4187 - val_accuracy: 0.7898 - val_loss: 0.4509
# Epoch 39/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8152 - loss: 0.4179 - val_accuracy: 0.7894 - val_loss: 0.4504
# Epoch 40/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8154 - loss: 0.4172 - val_accuracy: 0.7884 - val_loss: 0.4499
# Epoch 41/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8158 - loss: 0.4165 - val_accuracy: 0.7884 - val_loss: 0.4495
# Epoch 42/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8158 - loss: 0.4159 - val_accuracy: 0.7880 - val_loss: 0.4490
# Epoch 43/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.8160 - loss: 0.4153 - val_accuracy: 0.7882 - val_loss: 0.4486
# Epoch 44/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8159 - loss: 0.4147 - val_accuracy: 0.7868 - val_loss: 0.4481
# Epoch 45/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8166 - loss: 0.4141 - val_accuracy: 0.7872 - val_loss: 0.4477
# Epoch 46/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8166 - loss: 0.4136 - val_accuracy: 0.7864 - val_loss: 0.4473
# Epoch 47/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8169 - loss: 0.4131 - val_accuracy: 0.7866 - val_loss: 0.4469
# Epoch 48/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8170 - loss: 0.4126 - val_accuracy: 0.7870 - val_loss: 0.4465
# Epoch 49/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.8172 - loss: 0.4121 - val_accuracy: 0.7870 - val_loss: 0.4461
# Epoch 50/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8171 - loss: 0.4116 - val_accuracy: 0.7870 - val_loss: 0.4457
# Epoch 51/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8175 - loss: 0.4112 - val_accuracy: 0.7872 - val_loss: 0.4453
# Epoch 52/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8175 - loss: 0.4107 - val_accuracy: 0.7876 - val_loss: 0.4449
# Epoch 53/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.8179 - loss: 0.4103 - val_accuracy: 0.7878 - val_loss: 0.4445
# Epoch 54/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8179 - loss: 0.4099 - val_accuracy: 0.7884 - val_loss: 0.4442
# Epoch 55/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8177 - loss: 0.4094 - val_accuracy: 0.7894 - val_loss: 0.4438
# Epoch 56/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.8181 - loss: 0.4090 - val_accuracy: 0.7898 - val_loss: 0.4434
# Epoch 57/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8185 - loss: 0.4086 - val_accuracy: 0.7906 - val_loss: 0.4431
# Epoch 58/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8183 - loss: 0.4082 - val_accuracy: 0.7906 - val_loss: 0.4427
# Epoch 59/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8186 - loss: 0.4078 - val_accuracy: 0.7912 - val_loss: 0.4424
# Epoch 60/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8184 - loss: 0.4075 - val_accuracy: 0.7912 - val_loss: 0.4420
# Epoch 61/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8179 - loss: 0.4071 - val_accuracy: 0.7920 - val_loss: 0.4417
# Epoch 62/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8181 - loss: 0.4067 - val_accuracy: 0.7924 - val_loss: 0.4413
# Epoch 63/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8181 - loss: 0.4063 - val_accuracy: 0.7922 - val_loss: 0.4410
# Epoch 64/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8186 - loss: 0.4060 - val_accuracy: 0.7920 - val_loss: 0.4407
# Epoch 65/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8190 - loss: 0.4056 - val_accuracy: 0.7922 - val_loss: 0.4404
# Epoch 66/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8190 - loss: 0.4052 - val_accuracy: 0.7922 - val_loss: 0.4400
# Epoch 67/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8193 - loss: 0.4048 - val_accuracy: 0.7926 - val_loss: 0.4397
# Epoch 68/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8195 - loss: 0.4045 - val_accuracy: 0.7930 - val_loss: 0.4394
# Epoch 69/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8202 - loss: 0.4041 - val_accuracy: 0.7932 - val_loss: 0.4391
# Epoch 70/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8204 - loss: 0.4037 - val_accuracy: 0.7938 - val_loss: 0.4388
# Epoch 71/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8205 - loss: 0.4034 - val_accuracy: 0.7932 - val_loss: 0.4385
# Epoch 72/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8207 - loss: 0.4030 - val_accuracy: 0.7936 - val_loss: 0.4382
# Epoch 73/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8207 - loss: 0.4027 - val_accuracy: 0.7940 - val_loss: 0.4380
# Epoch 74/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.8206 - loss: 0.4023 - val_accuracy: 0.7942 - val_loss: 0.4377
# Epoch 75/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8204 - loss: 0.4019 - val_accuracy: 0.7948 - val_loss: 0.4374
# Epoch 76/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.8208 - loss: 0.4016 - val_accuracy: 0.7944 - val_loss: 0.4371
# Epoch 77/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8206 - loss: 0.4012 - val_accuracy: 0.7948 - val_loss: 0.4369
# Epoch 78/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8207 - loss: 0.4009 - val_accuracy: 0.7950 - val_loss: 0.4366
# Epoch 79/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8206 - loss: 0.4005 - val_accuracy: 0.7946 - val_loss: 0.4363
# Epoch 80/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8208 - loss: 0.4001 - val_accuracy: 0.7952 - val_loss: 0.4361
# Epoch 81/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8212 - loss: 0.3998 - val_accuracy: 0.7950 - val_loss: 0.4358
# Epoch 82/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8213 - loss: 0.3994 - val_accuracy: 0.7954 - val_loss: 0.4356
# Epoch 83/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.8215 - loss: 0.3990 - val_accuracy: 0.7960 - val_loss: 0.4353
# Epoch 84/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8218 - loss: 0.3987 - val_accuracy: 0.7960 - val_loss: 0.4351
# Epoch 85/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8223 - loss: 0.3983 - val_accuracy: 0.7958 - val_loss: 0.4348
# Epoch 86/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8222 - loss: 0.3980 - val_accuracy: 0.7962 - val_loss: 0.4346
# Epoch 87/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8221 - loss: 0.3976 - val_accuracy: 0.7962 - val_loss: 0.4344
# Epoch 88/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.8225 - loss: 0.3972 - val_accuracy: 0.7960 - val_loss: 0.4341
# Epoch 89/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8224 - loss: 0.3969 - val_accuracy: 0.7964 - val_loss: 0.4339
# Epoch 90/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8225 - loss: 0.3965 - val_accuracy: 0.7964 - val_loss: 0.4337
# Epoch 91/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.8226 - loss: 0.3962 - val_accuracy: 0.7968 - val_loss: 0.4335
# Epoch 92/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8226 - loss: 0.3958 - val_accuracy: 0.7970 - val_loss: 0.4333
# Epoch 93/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8230 - loss: 0.3954 - val_accuracy: 0.7970 - val_loss: 0.4331
# Epoch 94/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8229 - loss: 0.3951 - val_accuracy: 0.7968 - val_loss: 0.4329
# Epoch 95/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8231 - loss: 0.3947 - val_accuracy: 0.7970 - val_loss: 0.4327
# Epoch 96/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8232 - loss: 0.3944 - val_accuracy: 0.7966 - val_loss: 0.4325
# Epoch 97/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8236 - loss: 0.3940 - val_accuracy: 0.7962 - val_loss: 0.4323
# Epoch 98/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8236 - loss: 0.3936 - val_accuracy: 0.7970 - val_loss: 0.4321
# Epoch 99/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8238 - loss: 0.3933 - val_accuracy: 0.7972 - val_loss: 0.4319
# Epoch 100/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8237 - loss: 0.3929 - val_accuracy: 0.7978 - val_loss: 0.4317

# %%
plt.plot(history4.history['loss'])
plt.plot(history4.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()

# %%
# 테스트셋 평가

rnn_model = keras.models.load_model(os.path.join(base_path, 'best-gru-model.keras'))
rnn_model.evaluate(test_seq, test_target)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8039 - loss: 0.4297
# [0.4291016459465027, 0.8022000193595886]

# %% [markdown]
# # ■ 양방향 LSTM
# Bidirectional-LSTM, Bi-LSTM
# RNN 이나 LSTM 은 일반 신경망과 다르게 시퀀스 또는 시계열 데이터 처리에 특화되어 은닉층에서 과거의 정보를 기억할 수 있습니다.  그러나, 순환 신경망의 구조적 특성상 데이터가 **'입력 순'** 으로 처리되기 때문에 이전 시점의 정보만 활용할 수 밖에 없는 단점이 존재합니다.  문장이 길어 질수록(시퀀스가 길어질수록) 성능이 저하될 수 밖에 없습니다. 다음 예문을 봅시다
#
# > ios 앱 <u>[   ]</u>은 맥북이 필요합니다
#
# > ios 앱 <u>개발</u>은 맥북이 필요합니다
#
# 한국어를 사용하는 우리에겐 어렵지 않게 빈칸에 들어가는 단어를 유추해낼수 있다.  그러나 일반적인 RNN 이나 LSTM 에서 순차적으로 입력되는 시퀀스를 통해 앞에 입력된 데이터인 'ios' 와 '앱' 이라는 단어만 가지고 빈칸에 들어갈 '개발' 이라는 단어를 유추해 내기엔 정보가 매우 부족하다.
#
# 문장 **앞부분보단, 뒷부분에 중요한 정보**가 존재하기 때문입니다.
#
# 따라서! 자연어 처리에서 입력 데이터의 '정방향' 처리만큼 **'역방향'** 처리도 중요합니다!
#
# **양방향 LSTM (Bidirectional LSTM)** 은 기존 LSTM 계측에 역방향으로 처리하는  LSTM 계층을 하나 더 추가해 양방향에서 문장의 패턴을 분석할수 있도록 구성되어 있습니다.  입력 문장을 양방향에서 처리하므로 시퀀스 길이가 길어진다 하더라도 정보 손실 없이 처리가 가능
#
#
# **양방향 LSTM 구조**
#
# ![](https://blog.kakaocdn.net/dn/ySdrH/btrZrwllBAV/T6RqmCYAkavMJ1iZ2gTi80/img.png)

# %% [markdown]
# ## Bidirectional
# **tf.keras.layers.Bidirectional**
# - RNN 에 적용하는 양방향 (bidirectional) wrapper
# - https://www.tensorflow.org/api_docs/python/tf/keras/layers/Bidirectional
# - Bidirectional 로 설정할 RNN layer 는 **return_sequences=True**: 모든 time step 에서 출력을 반환해야 하므로 설정해야 한다
#
# ```python
# tf.keras.layers.Bidirectional(
#     layer,
#     merge_mode='concat',
#     weights=None,
#     backward_layer=None,
#     **kwargs
# )
# ```

# %% [markdown]
# ## TimeDistributed
# **tf.keras.layers.TimeDistributed**
# - 각 time step 에서 출력된 output 을 내부에 선언해준 레이어와 연결시켜주는 역할
# - TimeDistributed 또한 Wrapper 다 (Wrapper 상속객체)
# - https://www.tensorflow.org/api_docs/python/tf/keras/layers/TimeDistributed
# - 출력 형태는 (batch_size, time_steps, num_classes)
#
# ```python
# tf.keras.layers.TimeDistributed(
#     layer, **kwargs
# )
# ```

# %% [markdown]
# 양방향 LSTM 모델을 정의할때 주의점!
# - 정방향, 역방향 LSTM 계측 모두 출력값을 연결해야 하기 때문에, return_sequences 인자를 반드시 True 로 해야 함.
# - 또한 Dense 계층을 TimeDistributed 래퍼를 사용해 3차원 텐서를 입력받을수 있게 확장해야 한다

# %% [markdown]
# ## 모델 정의

# %%
from tensorflow.keras.layers import Bidirectional, Embedding, \
                Input, LSTM, TimeDistributed, Dense, Flatten

# %%
model5 = keras.Sequential()

model5.add(Input(shape=(max_len,))) #(100,)
model5.add(Embedding(input_dim=500, output_dim=16))
model5.add(Bidirectional(LSTM(8, dropout=0.3, return_sequences=True)))
model5.add(TimeDistributed(Dense(1, activation='sigmoid')))
model5.add(Flatten())
model5.add(Dense(1, activation='sigmoid'))

model5.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_4 (Embedding)         │ (None, 100, 16)        │         8,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 100, 16)        │         1,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed                │ (None, 100, 1)         │            17 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,718 (37.96 KB)
#  Trainable params: 9,718 (37.96 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate=1e-4)
model5.compile(optimizer=rmsprop, loss='binary_crossentropy',
              metrics=['accuracy'])

checkpoint_cb = keras.callbacks.ModelCheckpoint(
    os.path.join(base_path, 'best-biLSTM-model.keras'),
    save_best_only=True)
early_stopping_cb = keras.callbacks.EarlyStopping(patience=3,
                                                  restore_best_weights=True)

history5 = model5.fit(train_seq, train_target, epochs=100, batch_size=64,
                    validation_data=(val_seq, val_target),
                    callbacks=[checkpoint_cb, early_stopping_cb])
# Out:
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.5033 - loss: 0.7136 - val_accuracy: 0.4836 - val_loss: 0.6933
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.5031 - loss: 0.6932 - val_accuracy: 0.4940 - val_loss: 0.6932
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.5026 - loss: 0.6932 - val_accuracy: 0.5046 - val_loss: 0.6931
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.5080 - loss: 0.6931 - val_accuracy: 0.4966 - val_loss: 0.6931
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.5093 - loss: 0.6930 - val_accuracy: 0.4996 - val_loss: 0.6930
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.5108 - loss: 0.6930 - val_accuracy: 0.4986 - val_loss: 0.6930
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 29ms/step - accuracy: 0.5158 - loss: 0.6929 - val_accuracy: 0.5082 - val_loss: 0.6930
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.5160 - loss: 0.6928 - val_accuracy: 0.5036 - val_loss: 0.6929
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.5207 - loss: 0.6927 - val_accuracy: 0.5140 - val_loss: 0.6928
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.5183 - loss: 0.6926 - val_accuracy: 0.5116 - val_loss: 0.6927
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.5243 - loss: 0.6924 - val_accuracy: 0.5172 - val_loss: 0.6925
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.5273 - loss: 0.6922 - val_accuracy: 0.5178 - val_loss: 0.6925
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.5299 - loss: 0.6920 - val_accuracy: 0.5208 - val_loss: 0.6922
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.5311 - loss: 0.6918 - val_accuracy: 0.5232 - val_loss: 0.6920
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.5356 - loss: 0.6914 - val_accuracy: 0.5276 - val_loss: 0.6918
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.5380 - loss: 0.6912 - val_accuracy: 0.5300 - val_loss: 0.6916
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.5385 - loss: 0.6908 - val_accuracy: 0.5280 - val_loss: 0.6914
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.5434 - loss: 0.6904 - val_accuracy: 0.5362 - val_loss: 0.6909
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.5414 - loss: 0.6900 - val_accuracy: 0.5394 - val_loss: 0.6907
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.5482 - loss: 0.6895 - val_accuracy: 0.5418 - val_loss: 0.6902
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.5466 - loss: 0.6890 - val_accuracy: 0.5402 - val_loss: 0.6897
# Epoch 22/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.5513 - loss: 0.6887 - val_accuracy: 0.5396 - val_loss: 0.6898
# Epoch 23/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.5510 - loss: 0.6879 - val_accuracy: 0.5402 - val_loss: 0.6892
# Epoch 24/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.5527 - loss: 0.6876 - val_accuracy: 0.5436 - val_loss: 0.6887
# Epoch 25/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.5520 - loss: 0.6867 - val_accuracy: 0.5458 - val_loss: 0.6885
# Epoch 26/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - accuracy: 0.5574 - loss: 0.6864 - val_accuracy: 0.5428 - val_loss: 0.6884
# Epoch 27/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - accuracy: 0.5600 - loss: 0.6856 - val_accuracy: 0.5444 - val_loss: 0.6880
# Epoch 28/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.5571 - loss: 0.6850 - val_accuracy: 0.5476 - val_loss: 0.6877
# Epoch 29/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.5613 - loss: 0.6844 - val_accuracy: 0.5506 - val_loss: 0.6870
# Epoch 30/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - accuracy: 0.5632 - loss: 0.6835 - val_accuracy: 0.5490 - val_loss: 0.6866
# Epoch 31/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.5625 - loss: 0.6828 - val_accuracy: 0.5508 - val_loss: 0.6859
# Epoch 32/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.5692 - loss: 0.6818 - val_accuracy: 0.5528 - val_loss: 0.6854
# Epoch 33/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.5723 - loss: 0.6809 - val_accuracy: 0.5558 - val_loss: 0.6836
# Epoch 34/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.5755 - loss: 0.6794 - val_accuracy: 0.5574 - val_loss: 0.6832
# Epoch 35/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.5774 - loss: 0.6779 - val_accuracy: 0.5546 - val_loss: 0.6827
# Epoch 36/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.5830 - loss: 0.6762 - val_accuracy: 0.5562 - val_loss: 0.6812
# Epoch 37/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.5873 - loss: 0.6738 - val_accuracy: 0.5674 - val_loss: 0.6795
# Epoch 38/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - accuracy: 0.5912 - loss: 0.6716 - val_accuracy: 0.5730 - val_loss: 0.6770
# Epoch 39/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.5968 - loss: 0.6683 - val_accuracy: 0.5782 - val_loss: 0.6759
# Epoch 40/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.6015 - loss: 0.6648 - val_accuracy: 0.5912 - val_loss: 0.6706
# Epoch 41/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.6208 - loss: 0.6596 - val_accuracy: 0.6104 - val_loss: 0.6637
# Epoch 42/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.6507 - loss: 0.6501 - val_accuracy: 0.6512 - val_loss: 0.6415
# Epoch 43/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.6764 - loss: 0.6306 - val_accuracy: 0.6806 - val_loss: 0.6230
# Epoch 44/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.7025 - loss: 0.6099 - val_accuracy: 0.6964 - val_loss: 0.6041
# Epoch 45/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.7185 - loss: 0.5887 - val_accuracy: 0.7152 - val_loss: 0.5814
# Epoch 46/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.7356 - loss: 0.5652 - val_accuracy: 0.7322 - val_loss: 0.5597
# Epoch 47/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.7493 - loss: 0.5402 - val_accuracy: 0.7446 - val_loss: 0.5377
# Epoch 48/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.7554 - loss: 0.5228 - val_accuracy: 0.7480 - val_loss: 0.5255
# Epoch 49/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.7644 - loss: 0.5066 - val_accuracy: 0.7584 - val_loss: 0.5154
# Epoch 50/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.7713 - loss: 0.4952 - val_accuracy: 0.7614 - val_loss: 0.5053
# Epoch 51/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - accuracy: 0.7784 - loss: 0.4836 - val_accuracy: 0.7646 - val_loss: 0.5025
# Epoch 52/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 24ms/step - accuracy: 0.7830 - loss: 0.4750 - val_accuracy: 0.7714 - val_loss: 0.4946
# Epoch 53/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.7875 - loss: 0.4682 - val_accuracy: 0.7712 - val_loss: 0.4919
# Epoch 54/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.7927 - loss: 0.4603 - val_accuracy: 0.7724 - val_loss: 0.4865
# Epoch 55/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.7924 - loss: 0.4561 - val_accuracy: 0.7710 - val_loss: 0.4873
# Epoch 56/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.7936 - loss: 0.4526 - val_accuracy: 0.7850 - val_loss: 0.4733
# Epoch 57/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - accuracy: 0.7996 - loss: 0.4459 - val_accuracy: 0.7782 - val_loss: 0.4780
# Epoch 58/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.8037 - loss: 0.4407 - val_accuracy: 0.7836 - val_loss: 0.4747
# Epoch 59/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.8036 - loss: 0.4388 - val_accuracy: 0.7776 - val_loss: 0.4741

# %%
plt.plot(history5.history['loss'])
plt.plot(history5.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()
